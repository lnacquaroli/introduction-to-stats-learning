# %% [markdown]
# 11. In this problem we will investigate the $t$-statistic for the null hypothesis
#
# $H_0: \beta = 0$
#
# in simple linear regression without an intercept. To begin, we generate a predictor $x$ and a response $y$ as follows.

# %%
library(ggplot2)

# %%
set.seed(1)
x <- rnorm(100)
y <- 2 * x + rnorm(100)

# %% [markdown]
# (a) Perform a simple linear regression of `y` onto `x`, without an intercept.
#
# Report the coefficient estimate $\hat{\beta}$, the standard error of this coefficient estimate, and the $t$-statistic and $p$-value associated with the null hypothesis $H_0: \beta = 0$.
#
# Comment on these results. (You can perform regression without an intercept using the command `lm(y ∼ x + 0)`.)

# %%
lm.fit <- lm(y ~ x + 0) # also can be done with - 1 instead of + 0
summary(lm.fit)
# Out:
# Call:
# lm(formula = y ~ x + 0)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9154 -0.6472 -0.1771  0.5056  2.3109
#
# Coefficients:
#   Estimate Std. Error t value Pr(>|t|)
# x   1.9939     0.1065   18.73   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9586 on 99 degrees of freedom
# Multiple R-squared:  0.7798,	Adjusted R-squared:  0.7776
# F-statistic: 350.7 on 1 and 99 DF,  p-value: < 2.2e-16

# %% [markdown]
# The estimated coefficient $\hat{\beta}$ equals 1.9939, which means that the slope of the regression is approximately 2.
#
# The standard error of the coefficient is 0.1065.
#
# The $t$-statistic shows a large value of 18.73, with an associated low $p$-value, $< 2 \times 10^{-16}$. This means that the null hypothesis is rejected in favor of the alternative hypothesis, that a linear relation exists between the predictor and the reponse.
#
# According to the $R^2$ value, about 78% of the variability is explained with the model.
#
# The $F$-statistic also is very high, with an associated low $p$-value, which indicates that the relation between `x`and `y` is strong.

# %%
df <- data.frame(x = x, y = y)
g <- ggplot(df, aes(x, y)) +
    theme_minimal() +
    geom_point() +
    stat_smooth(method = lm)
g
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# (b) Now perform a simple linear regression of `x` onto `y` without an intercept, and report the coefficient estimate, its standard error, and the corresponding $t$-statistic and $p$-values associated with the null hypothesis
#
# $H_0: \beta = 0$.
#
# Comment on these results.

# %%
lm.fit2 <- lm(x ~ y - 1)
summary(lm.fit2)
# Out:
# Call:
# lm(formula = x ~ y - 1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.8699 -0.2368  0.1030  0.2858  0.8938
#
# Coefficients:
#   Estimate Std. Error t value Pr(>|t|)
# y  0.39111    0.02089   18.73   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4246 on 99 degrees of freedom
# Multiple R-squared:  0.7798,	Adjusted R-squared:  0.7776
# F-statistic: 350.7 on 1 and 99 DF,  p-value: < 2.2e-16

# %% [markdown]
# The estimated coefficient $\hat{\beta}$ equals 0.39111, which means that the slope of the regression is approximately 0.4.
#
# The standard error of the coefficient is 0.02089.
#
# The $t$-statistic shows the same large value of 18.73 as before, with an associated low $p$-value, $< 2 \times 10^{-16}$. This means that the null hypothesis is rejected in favor of the alternative hypothesis, that a linear relation exists between the predictor and the reponse.
#
# According to the $R^2$ value, about 78% of the variability is explained with the model. Same result as above.
#
# The $F$-statistic also is very high, with an associated low $p$-value, which indicates that the relation between `x`and `y` is strong.
#
# The results show a difference in the coefficient estimate values. This is because we are regressing either `x` on `y` or the other way around. The slope, coefficient estimate, is larger  when regressing `y` on `x`. The relation between these two coefficient estimates is 5.
#
# We could say that flipping the response and the predictor order the coefficient gets inversed.
#
# The rest of the results remain unchanged.

# %%
coef(lm.fit)
# Out:
#        x
# 1.993876

# %%
coef(lm.fit2)
# Out:
#         y
# 0.3911145

# %%
g2 <- ggplot(df, aes(y, x)) +
    theme_minimal() +
    geom_point() +
    stat_smooth(method = lm)
g2
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# (f) In `R`, show that when regression is performed with an intercept, the $t$-statistic for $H_0 : \beta_1 = 0$ is the same for the regression of `y` onto `x` as it is for the regression of `x` onto `y`.

# %%
lm.fit3 <- lm(y ~ x)
summary(lm.fit3)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8768 -0.6138 -0.1395  0.5394  2.3462
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.03769    0.09699  -0.389    0.698
# x            1.99894    0.10773  18.556   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9628 on 98 degrees of freedom
# Multiple R-squared:  0.7784,	Adjusted R-squared:  0.7762
# F-statistic: 344.3 on 1 and 98 DF,  p-value: < 2.2e-16

# %%
lm.fit4 <- lm(x ~ y)
summary(lm.fit4)
# Out:
# Call:
# lm(formula = x ~ y)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.90848 -0.28101  0.06274  0.24570  0.85736
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03880    0.04266    0.91    0.365
# y            0.38942    0.02099   18.56   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4249 on 98 degrees of freedom
# Multiple R-squared:  0.7784,	Adjusted R-squared:  0.7762
# F-statistic: 344.3 on 1 and 98 DF,  p-value: < 2.2e-16
